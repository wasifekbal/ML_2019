# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


titanic=pd.read_csv('titanic.csv')
x= titanic.groupby(['Embarked','Sex'])
x.sum()
# Out:
#                  PassengerId  Survived  Pclass       Age  SibSp  Parch  \
# Embarked Sex
# C        female        31924        64     126   1729.00     40     36
#          male          42896        29     191   2276.92     25     25
# Q        female        13469        27     104    291.50      8      8
#          male          18709         3     120    495.00     25      5
# S        female        89058       140     446   5165.50    170    160
#          male         200438        77    1068  11147.25    198    106
#
#                       Fare
# Embarked Sex
# C        female  5487.3958
#          male    4584.9004
# Q        female   454.8585
#          male     567.3958
# S        female  7864.4085
#          male    9574.9903

# %%
sns.barplot(x='Embarked',y='Survived',data=titanic, hue='Sex')

# %%
titanic.groupby('Sex').sum()
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865

# %%
sns.barplot(x='Sex',y='Survived',data=titanic)

# %%
titanic.iloc[15:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ...

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#bar =titanic.groupby('Pclass').sum()
total_num = titanic['Pclass'].value_counts().reset_index()
total_num.set_index('index')
# Out:
#        Pclass
# index
# 3         491
# 1         216
# 2         184

# %%
class_svd = titanic.groupby('Pclass').sum()
class_svd['Survived'].reset_index().set_index('Pclass')
#class_svd['Survived']
#plt.pie(var,labels=var.index,autopct='%0.2f%%')

#sns.barplot(x='Pclass',y='Survived',data=titanic, hue='Sex')
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
mega = class_svd.merge(total_num,left_on='Pclass',right_on='index')
sns.barplot(x='index',y='',data=tips, hue='smoker')
# Out:
#    PassengerId  Survived      Age  SibSp  Parch        Fare  index  Pclass
# 0        99705       136  7111.42     90     77  18177.4125      1     216
# 1        82056        87  5168.83     74     70   3801.8417      2     184
# 2       215625       119  8924.92    302    193   6714.6951      3     491

# %%
var = mega[['index','Pclass','Survived']]
var
#sns.barplot(x='index',y='Pclass',data=var)
# Out:
#    index  Pclass  Survived
# 0      1     216       136
# 1      2     184        87
# 2      3     491       119
